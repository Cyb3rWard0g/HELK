# %% [markdown]
# # <font color=purple>Basic Data Manipulation & Visualization</font>
# --------------------------------------------------------------------
# # <font color=blue>ATT&CK Tactic:</font><font color=green> Lateral Movement</font>
# ## <font color=green>Goals:</font>
# ------------
# * Show basic ES join queries
# * Learn a little bit of Pandas
# * Learn how to use matplotlib
# * Learn Nodes and Edges format for a Network Graph

# %% [markdown]
# # Import Modules

# %%
from elasticsearch import Elasticsearch
from pandas.io.json import json_normalize
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import re
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, Image

# %% [markdown]
# # Hunting for

# %%
display(Image('velop/data_science/Images/LM_Basic_Shells.jpg', embed=True))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-41-a32ed13a4a8f> in <module>()
# ----> 1 Image(url='https://github.com/Cyb3rWard0g/HELK/develop/data_science/Images/LM_Basic_Shells.jpg', embed=True)
#
# NameError: name 'Image' is not defined

# %% [markdown]
# # Connect to your ES via SSH Tunnel

# %%
es = Elasticsearch(['127.0.0.1'], port=9200, timeout=480)

# %% [markdown]
# ## Query your ES for Successful Authentication Logs

# %%
successful_logon_query=es.search(index='winlogbeat-*', 
    body = {
        'size': 10000,
        'query': {
            'bool': {
               'must': [
                    {"match" : {'source_name': "Microsoft-Windows-Security-Auditing" }},
                    {"match": {'event_id': 4624}},
                    {"match": {'event_data.LogonType': 3}}
               ],
               'must_not': [
                    {"match" : {'event_data.IpAddress': "::1" }},
                    {"match" : {'event_data.IpAddress': "172.18.39.2" }},
                    {"match": {'event_data.TargetUserName': "ANONYMOUS LOGON"}}
               ],
               "filter": [
                    {"range" : {"@timestamp" : {"gt": "now-4d", "lt" : "now"}}}
               ]    
            }

        }
    })

# %% [markdown]
# ## Query your ES for Sysmon Network Logs

# %%
sysmon_network_query=es.search(index='winlogbeat-*', body = {
    'size': 10000,
    'query': {
        'bool': {
           'must': [
               {"match": {'source_name': 'Microsoft-Windows-Sysmon'}},
               {"match": {'event_id': 3}}
           ],
           'must_not': [
               {"match" : {'event_data.DestinationIp': "172.18.39.2" }}, 
               {"match" : {'event_data.User': "NT AUTHORITY\SYSTEM"}}
           ],
           "filter": [
                {"range" : {"@timestamp" : {"gt": "now-4d", "lt" : "now"}}}
           ]    
        }
        
    }
})

# %% [markdown]
# # Normalize JSON (results) data into a DataFrame

# %%
sl_normalized=json_normalize(map(lambda x: x["_source"],successful_logon_query['hits']['hits']))
sn_normalized=json_normalize(map(lambda x: x["_source"],sysmon_network_query['hits']['hits']))

# %%
sl_normalized.head(5)
# Out:
#                  @timestamp @version beat.hostname    beat.name beat.version  \
# 0  2017-08-23T16:08:41.770Z        1   VA-WK-HR001  VA-WK-HR001        5.2.1
# 1  2017-08-23T00:59:57.432Z        1        HFDC01       HFDC01        5.5.0
# 2  2017-08-23T00:24:56.830Z        1        HFDC01       HFDC01        5.5.0
# 3  2017-08-23T00:25:13.965Z        1        HFDC01       HFDC01        5.5.0
# 4  2017-08-23T00:29:57.020Z        1        HFDC01       HFDC01        5.5.0
#
#         computer_name event_data.AuthenticationPackageName  \
# 0  VA-WK-HR001.hf.com                             Kerberos
# 1       HFDC01.hf.com                             Kerberos
# 2       HFDC01.hf.com                             Kerberos
# 3       HFDC01.hf.com                             Kerberos
# 4       HFDC01.hf.com                             Kerberos
#
#   event_data.ImpersonationLevel       event_data.IpAddress event_data.IpPort  \
# 0                           NaN                          -                 -
# 1                        %%1840  fe80::2036:13d7:5626:b29b             61354
# 2                        %%1833  fe80::2036:13d7:5626:b29b             61250
# 3                        %%1833  fe80::2036:13d7:5626:b29b             61253
# 4                        %%1833  fe80::2036:13d7:5626:b29b             61265
#
#     ...   opcode process_id                           provider_guid  \
# 0   ...     Info        492  {54849625-5478-4994-A5BA-3E3B0328C30D}
# 1   ...     Info        484  {54849625-5478-4994-A5BA-3E3B0328C30D}
# 2   ...     Info        484  {54849625-5478-4994-A5BA-3E3B0328C30D}
# 3   ...     Info        484  {54849625-5478-4994-A5BA-3E3B0328C30D}
# 4   ...     Info        484  {54849625-5478-4994-A5BA-3E3B0328C30D}
#
#   record_number                          source_name  \
# 0        265922  Microsoft-Windows-Security-Auditing
# 1       8837698  Microsoft-Windows-Security-Auditing
# 2       8836390  Microsoft-Windows-Security-Auditing
# 3       8836396  Microsoft-Windows-Security-Auditing
# 4       8836435  Microsoft-Windows-Security-Auditing
#
#                                 tags   task thread_id         type version
# 0  [beats_input_codec_plain_applied]  Logon       400  wineventlog     NaN
# 1  [beats_input_codec_plain_applied]  Logon      4908  wineventlog     1.0
# 2  [beats_input_codec_plain_applied]  Logon       316  wineventlog     1.0
# 3  [beats_input_codec_plain_applied]  Logon       316  wineventlog     1.0
# 4  [beats_input_codec_plain_applied]  Logon       316  wineventlog     1.0
#
# [5 rows x 43 columns]

# %%
sn_normalized.head(5)
# Out:
#                  @timestamp @version  beat.hostname      beat.name  \
# 0  2017-08-24T03:21:49.107Z        1  VA-WK-ACCT002  VA-WK-ACCT002
# 1  2017-08-24T03:22:08.073Z        1  VA-WK-ACCT002  VA-WK-ACCT002
# 2  2017-08-24T03:22:21.813Z        1  VA-WK-ACCT002  VA-WK-ACCT002
# 3  2017-08-24T03:22:41.786Z        1  VA-WK-ACCT002  VA-WK-ACCT002
# 4  2017-08-24T03:22:48.016Z        1  VA-WK-ACCT002  VA-WK-ACCT002
#
#   beat.version         computer_name event_data.DestinationHostname  \
# 0        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
# 1        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
# 2        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
# 3        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
# 4        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
#
#   event_data.DestinationIp event_data.DestinationIsIpv6  \
# 0            172.18.39.105                        false
# 1            172.18.39.105                        false
# 2            172.18.39.105                        false
# 3            172.18.39.105                        false
# 4            172.18.39.105                        false
#
#   event_data.DestinationPort   ...                 source_name  \
# 0                         80   ...    Microsoft-Windows-Sysmon
# 1                         80   ...    Microsoft-Windows-Sysmon
# 2                         80   ...    Microsoft-Windows-Sysmon
# 3                         80   ...    Microsoft-Windows-Sysmon
# 4                         80   ...    Microsoft-Windows-Sysmon
#
#                                 tags  \
# 0  [beats_input_codec_plain_applied]
# 1  [beats_input_codec_plain_applied]
# 2  [beats_input_codec_plain_applied]
# 3  [beats_input_codec_plain_applied]
# 4  [beats_input_codec_plain_applied]
#
#                                                 task thread_id         type  \
# 0  Network connection detected (rule: NetworkConn...      1948  wineventlog
# 1  Network connection detected (rule: NetworkConn...      1948  wineventlog
# 2  Network connection detected (rule: NetworkConn...      1948  wineventlog
# 3  Network connection detected (rule: NetworkConn...      1948  wineventlog
# 4  Network connection detected (rule: NetworkConn...      1948  wineventlog
#
#     user.domain user.identifier user.name user.type version
# 0  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 1  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 2  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 3  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 4  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
#
# [5 rows x 41 columns]

# %% [markdown]
# # Clean Successful Logon DataFrame

# %%
sl_df=sl_normalized[sl_normalized["event_data.IpAddress"].str.contains('^(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$')]
sl_df=sl_df[~sl_df['event_data.TargetUserName'].str.contains('.*\$')]
sl_df['user'] = sl_df['event_data.TargetDomainName'] + '\\' + sl_df['event_data.TargetUserName']
sl_df.rename(columns={"event_data.IpAddress":"sourceip", "computer_name":"target"}, inplace=True)
sl_df_clean=sl_df[['sourceip', 'target', 'user', '@timestamp']].reset_index(drop=True)
sl_df_clean.head(10)
# Out:
#         sourceip                target         user                @timestamp
# 0  172.18.39.102         HFDC01.hf.com    HF\gwhite  2017-08-23T15:14:34.934Z
# 1  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T15:16:52.111Z
# 2  172.18.39.101         HFDC01.hf.com  HF\Bbaggins  2017-08-23T14:48:47.058Z
# 3  172.18.39.100         HFDC01.hf.com    HF\cbrown  2017-08-23T13:50:44.437Z
# 4  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T13:52:57.620Z
# 5  172.18.39.101  VA-WK-ACCT002.hf.com  HF\Bbaggins  2017-08-23T14:49:17.484Z
# 6  172.18.39.101  VA-WK-ACCT002.hf.com  HF\Bbaggins  2017-08-23T14:56:18.915Z
# 7  172.18.39.102  VA-WK-ACCT003.hf.com    HF\pdulce  2017-08-23T15:28:01.492Z
# 8  172.18.39.102  VA-WK-ACCT003.hf.com    HF\pdulce  2017-08-23T15:12:34.046Z
# 9  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T14:33:01.250Z

# %% [markdown]
# # Clean Sysmon Network DataFrame

# %%
sn_df=sn_normalized[sn_normalized["event_data.SourceIp"].str.contains('^(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$')]
sn_df.rename(columns={"event_data.SourceHostname":"source","event_data.SourceIp":"sourceip", "event_data.DestinationIp":"targetip", "event_data.User":"user"}, inplace=True)
sn_df_clean=sn_df[['source', 'targetip', 'user', '@timestamp']]
sn_df_clean.reset_index(drop=True)
sn_df_clean.head(10)
# Out:
#                  source       targetip         user                @timestamp
# 0  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:21:49.107Z
# 1  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:08.073Z
# 2  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:21.813Z
# 3  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:41.786Z
# 4  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:48.016Z
# 5  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:00.495Z
# 6  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:07.022Z
# 7  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:31.053Z
# 8  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:18.889Z
# 9  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:14.142Z

# %% [markdown]
# # Create an IP-Computer Map with Sysmon Network Logs

# %%
sysmon_ip_computer_reference=sn_df[['sourceip', 'computer_name']]
sysmon_ip_computer_reference = (sysmon_ip_computer_reference.drop_duplicates()).reset_index(drop=True)
sysmon_ip_computer_reference
# Out:
#         sourceip         computer_name
# 0  172.18.39.102  VA-WK-ACCT002.hf.com
# 1  172.18.39.103  VA-WK-ACCT003.hf.com
# 2  172.18.39.101    WK-VA-HR002.hf.com
# 3  172.18.39.100    VA-WK-HR001.hf.com

# %% [markdown]
# # Merge Successful Logon DF and IP-Computer Map

# %%
sl_df_merged=pd.merge(sl_df_clean,sysmon_ip_computer_reference,how="left",left_on="sourceip",right_on="sourceip")
sl_df_merged.head(10)
# Out:
#         sourceip                target         user                @timestamp  \
# 0  172.18.39.102         HFDC01.hf.com    HF\gwhite  2017-08-23T15:14:34.934Z
# 1  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T15:16:52.111Z
# 2  172.18.39.101         HFDC01.hf.com  HF\Bbaggins  2017-08-23T14:48:47.058Z
# 3  172.18.39.100         HFDC01.hf.com    HF\cbrown  2017-08-23T13:50:44.437Z
# 4  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T13:52:57.620Z
# 5  172.18.39.101  VA-WK-ACCT002.hf.com  HF\Bbaggins  2017-08-23T14:49:17.484Z
# 6  172.18.39.101  VA-WK-ACCT002.hf.com  HF\Bbaggins  2017-08-23T14:56:18.915Z
# 7  172.18.39.102  VA-WK-ACCT003.hf.com    HF\pdulce  2017-08-23T15:28:01.492Z
# 8  172.18.39.102  VA-WK-ACCT003.hf.com    HF\pdulce  2017-08-23T15:12:34.046Z
# 9  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T14:33:01.250Z
#
#           computer_name
# 0  VA-WK-ACCT002.hf.com
# 1  VA-WK-ACCT003.hf.com
# 2    WK-VA-HR002.hf.com
# 3    VA-WK-HR001.hf.com
# 4  VA-WK-ACCT003.hf.com
# 5    WK-VA-HR002.hf.com
# 6    WK-VA-HR002.hf.com
# 7  VA-WK-ACCT002.hf.com
# 8  VA-WK-ACCT002.hf.com
# 9  VA-WK-ACCT003.hf.com

# %% [markdown]
# # Merge Sysmon Network DF and IP-Computer Map

# %%
sn_df_merged=pd.merge(sn_df_clean,sysmon_ip_computer_reference,how="left",left_on="targetip",right_on="sourceip")
sn_df_merged.head(10)
# Out:
#                  source       targetip         user                @timestamp  \
# 0  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:21:49.107Z
# 1  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:08.073Z
# 2  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:21.813Z
# 3  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:41.786Z
# 4  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:48.016Z
# 5  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:00.495Z
# 6  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:07.022Z
# 7  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:31.053Z
# 8  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:18.889Z
# 9  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:14.142Z
#
#   sourceip computer_name
# 0      NaN           NaN
# 1      NaN           NaN
# 2      NaN           NaN
# 3      NaN           NaN
# 4      NaN           NaN
# 5      NaN           NaN
# 6      NaN           NaN
# 7      NaN           NaN
# 8      NaN           NaN
# 9      NaN           NaN

# %% [markdown]
# # Map IP-Computer in Successful Logon Dataframe

# %%
sl_df_resolved=sl_df_merged[['computer_name','target', 'user', '@timestamp']][sl_df_merged['computer_name'].notnull()]
sl_df_resolved.rename(columns={'computer_name':"source"}, inplace=True)
sl_df_resolved.reset_index(drop=True)
sl_df_resolved.head(10)
# Out:
#                  source                target         user  \
# 0  VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite
# 1  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 2    WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins
# 3    VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown
# 4  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 5    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 6    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 9  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
#
#                  @timestamp
# 0  2017-08-23T15:14:34.934Z
# 1  2017-08-23T15:16:52.111Z
# 2  2017-08-23T14:48:47.058Z
# 3  2017-08-23T13:50:44.437Z
# 4  2017-08-23T13:52:57.620Z
# 5  2017-08-23T14:49:17.484Z
# 6  2017-08-23T14:56:18.915Z
# 7  2017-08-23T15:28:01.492Z
# 8  2017-08-23T15:12:34.046Z
# 9  2017-08-23T14:33:01.250Z

# %% [markdown]
# # Map IP-Computer in Sysmon Network Dataframe

# %%
sn_df_merged.computer_name.fillna(sn_df_merged.targetip, inplace=True)
sn_df_resolved=sn_df_merged[['source','computer_name', 'user', '@timestamp']]
sn_df_resolved.rename(columns={'computer_name':'target'}, inplace=True)
sn_df_resolved.head(10)
# Out:
#                  source         target         user                @timestamp
# 0  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:21:49.107Z
# 1  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:08.073Z
# 2  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:21.813Z
# 3  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:41.786Z
# 4  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:48.016Z
# 5  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:00.495Z
# 6  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:07.022Z
# 7  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:31.053Z
# 8  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:18.889Z
# 9  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:23:14.142Z

# %% [markdown]
# # Stack Successful Logon and Sysmon Network DFs

# %%
sl_sn_appended = sl_df_resolved.append(sn_df_resolved)
sl_sn_appended = sl_sn_appended[['source', 'target', 'user']]
sl_sn_appended = (sl_sn_appended.drop_duplicates()).reset_index(drop=True)
sl_sn_appended
# Out:
#                   source                target         user
# 0   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite
# 1   VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 2     WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins
# 3     VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown
# 4     WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5   VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 6   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\pdulce
# 7   VA-WK-ACCT002.hf.com         172.18.39.105  HF\Bbaggins
# 8   VA-WK-ACCT003.hf.com         172.18.39.105    HF\pdulce
# 9   VA-WK-ACCT002.hf.com         65.52.108.154    HF\gwhite
# 10    WK-VA-HR002.hf.com          65.55.252.71  HF\Bbaggins
# 11    WK-VA-HR002.hf.com         172.18.39.105  HF\Bbaggins
# 12  VA-WK-ACCT003.hf.com         172.18.39.104    HF\pdulce
# 13  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com  HF\Bbaggins
# 14  VA-WK-ACCT003.hf.com    VA-WK-HR001.hf.com    HF\pdulce
# 15  VA-WK-ACCT003.hf.com         65.52.108.154   HF\shobbit
# 16    VA-WK-HR001.hf.com         40.117.100.83    HF\cbrown
# 17    VA-WK-HR001.hf.com          13.107.3.128    HF\cbrown
# 18    VA-WK-HR001.hf.com           13.107.5.88    HF\cbrown
# 19    VA-WK-HR001.hf.com        40.121.144.182    HF\cbrown

# %% [markdown]
# # Take Successful Logon DF and merge it with Sysmon Network DF

# %%
sl_sn_merged = pd.merge(sl_df_resolved,sn_df_resolved,how="left",left_on="target",right_on="source")
sl_sn_merged.head(10)
# Out:
#                source_x              target_x       user_x  \
# 0  VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite
# 1  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 2    WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins
# 3    VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown
# 4  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 5    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 6    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 8    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 9    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
#
#                @timestamp_x              source_y       target_y       user_y  \
# 0  2017-08-23T15:14:34.934Z                   NaN            NaN          NaN
# 1  2017-08-23T15:16:52.111Z                   NaN            NaN          NaN
# 2  2017-08-23T14:48:47.058Z                   NaN            NaN          NaN
# 3  2017-08-23T13:50:44.437Z                   NaN            NaN          NaN
# 4  2017-08-23T13:52:57.620Z                   NaN            NaN          NaN
# 5  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 6  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 7  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 8  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 9  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
#
#                @timestamp_y
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5  2017-08-24T03:21:49.107Z
# 6  2017-08-24T03:22:08.073Z
# 7  2017-08-24T03:22:21.813Z
# 8  2017-08-24T03:22:41.786Z
# 9  2017-08-24T03:22:48.016Z

# %% [markdown]
# # Use TIME to start looking for a few suspicious (Successful Auth & Sysmon Network Calls)

# %%
sl_sn_merged['@timestamp_x'] = pd.to_datetime(sl_sn_merged['@timestamp_x'])
sl_sn_merged['@timestamp_y'] = pd.to_datetime(sl_sn_merged['@timestamp_y'])

sl_sn_merged = sl_sn_merged[sl_sn_merged.apply(lambda x: (x['@timestamp_y'] - x['@timestamp_x']) < pd.Timedelta("280sec") and x['user_y'] == x['user_x'], axis=1)]

# %%
sl_sn_merged
# Out:
#                   source_x              target_x       user_x  \
# 2243    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2244    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2245    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2246    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2247    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2248    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2249    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2250    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2251    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2425    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2426    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2427    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2428    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2429    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2430    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2431    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2432    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2433    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2434    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2440    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2604    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2605    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2606    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2607    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2608    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2609    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2610    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2611    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2612    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2613    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# ...                    ...                   ...          ...
# 6991    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 6992    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 6993    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 6994    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7173    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7174    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7175    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7176    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7179    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7321    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7322    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7323    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7324    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7325    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7326    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7327    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7328    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7329    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7330    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7331    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7332    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 8060  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8106  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8110  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8223  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8224  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8225  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8226  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8628  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8796  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
#
#                 @timestamp_x              source_y       target_y  \
# 2243 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2244 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2245 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2246 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2247 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2248 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2249 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2250 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2251 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2425 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2426 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2427 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2428 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2429 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2430 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2431 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2432 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2433 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2434 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2440 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2604 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2605 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2606 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2607 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2608 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2609 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2610 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2611 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2612 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2613 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# ...                      ...                   ...            ...
# 6991 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 6992 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 6993 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 6994 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7173 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7174 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7175 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7176 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7179 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7321 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7322 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7323 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7324 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7325 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7326 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7327 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7328 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7329 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7330 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7331 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 7332 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 8060 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
# 8106 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
# 8110 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
# 8223 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
# 8224 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
# 8225 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
# 8226 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
# 8628 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
# 8796 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
#
#            user_y            @timestamp_y
# 2243  HF\Bbaggins 2017-08-23 14:58:38.901
# 2244  HF\Bbaggins 2017-08-23 14:59:18.772
# 2245  HF\Bbaggins 2017-08-23 14:57:05.445
# 2246  HF\Bbaggins 2017-08-23 14:57:15.928
# 2247  HF\Bbaggins 2017-08-23 14:57:20.808
# 2248  HF\Bbaggins 2017-08-23 14:57:25.680
# 2249  HF\Bbaggins 2017-08-23 14:59:47.640
# 2250  HF\Bbaggins 2017-08-23 15:00:23.267
# 2251  HF\Bbaggins 2017-08-23 15:00:33.162
# 2425  HF\Bbaggins 2017-08-23 14:56:59.610
# 2426  HF\Bbaggins 2017-08-23 14:57:11.056
# 2427  HF\Bbaggins 2017-08-23 14:57:37.375
# 2428  HF\Bbaggins 2017-08-23 14:57:42.491
# 2429  HF\Bbaggins 2017-08-23 14:57:48.095
# 2430  HF\Bbaggins 2017-08-23 14:58:02.712
# 2431  HF\Bbaggins 2017-08-23 14:58:13.440
# 2432  HF\Bbaggins 2017-08-23 14:59:35.734
# 2433  HF\Bbaggins 2017-08-23 14:59:52.093
# 2434  HF\Bbaggins 2017-08-23 15:00:52.959
# 2440  HF\Bbaggins 2017-08-23 14:58:44.811
# 2604  HF\Bbaggins 2017-08-23 14:59:14.071
# 2605  HF\Bbaggins 2017-08-23 14:57:52.724
# 2606  HF\Bbaggins 2017-08-23 14:58:07.593
# 2607  HF\Bbaggins 2017-08-23 14:59:30.151
# 2608  HF\Bbaggins 2017-08-23 14:59:35.734
# 2609  HF\Bbaggins 2017-08-23 14:59:41.703
# 2610  HF\Bbaggins 2017-08-23 15:00:02.235
# 2611  HF\Bbaggins 2017-08-23 15:00:07.435
# 2612  HF\Bbaggins 2017-08-23 15:00:17.330
# 2613  HF\Bbaggins 2017-08-23 15:00:27.473
# ...           ...                     ...
# 6991  HF\Bbaggins 2017-08-23 15:00:07.435
# 6992  HF\Bbaggins 2017-08-23 15:00:17.330
# 6993  HF\Bbaggins 2017-08-23 15:00:27.473
# 6994  HF\Bbaggins 2017-08-23 15:00:43.058
# 7173  HF\Bbaggins 2017-08-23 14:57:04.227
# 7174  HF\Bbaggins 2017-08-23 14:57:30.554
# 7175  HF\Bbaggins 2017-08-23 14:59:02.284
# 7176  HF\Bbaggins 2017-08-23 14:59:02.772
# 7179  HF\Bbaggins 2017-08-23 15:00:47.758
# 7321  HF\Bbaggins 2017-08-23 14:57:57.840
# 7322  HF\Bbaggins 2017-08-23 14:58:17.582
# 7323  HF\Bbaggins 2017-08-23 14:58:32.884
# 7324  HF\Bbaggins 2017-08-23 14:58:50.663
# 7325  HF\Bbaggins 2017-08-23 14:58:55.126
# 7326  HF\Bbaggins 2017-08-23 14:59:08.377
# 7327  HF\Bbaggins 2017-08-23 14:59:23.966
# 7328  HF\Bbaggins 2017-08-23 14:59:42.198
# 7329  HF\Bbaggins 2017-08-23 14:59:57.535
# 7330  HF\Bbaggins 2017-08-23 15:00:13.372
# 7331  HF\Bbaggins 2017-08-23 15:00:37.863
# 7332  HF\Bbaggins 2017-08-23 15:00:57.907
# 8060    HF\pdulce 2017-08-23 15:31:54.620
# 8106    HF\pdulce 2017-08-23 15:32:38.693
# 8110    HF\pdulce 2017-08-23 15:32:22.670
# 8223    HF\pdulce 2017-08-23 15:32:04.600
# 8224    HF\pdulce 2017-08-23 15:32:32.875
# 8225    HF\pdulce 2017-08-23 15:32:28.616
# 8226    HF\pdulce 2017-08-23 15:32:06.903
# 8628    HF\pdulce 2017-08-23 15:32:17.065
# 8796    HF\pdulce 2017-08-23 15:32:12.440
#
# [114 rows x 8 columns]

# %% [markdown]
# # Grab suspicious Successful Logon activity

# %%
sl_df_split = sl_sn_merged[['source_x', 'target_x', 'user_x']]
sl_df_split.rename(columns={'source_x':'source', 'target_x':'target', 'user_x':'user'}, inplace=True)
sl_df_split = (sl_df_split.drop_duplicates()).reset_index(drop=True)
sl_df_split
# Out:
#                  source                target         user
# 0    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce

# %% [markdown]
# # Grab suspicious Sysmon Network activity

# %%
sn_df_split = sl_sn_merged[['source_y', 'target_y', 'user_y']]
sn_df_split.rename(columns={'source_y':'source', 'target_y':'target', 'user_y':'user'}, inplace=True)
sn_df_split = (sn_df_split.drop_duplicates()).reset_index(drop=True)
sn_df_split
# Out:
#                  source         target         user
# 0  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 1  VA-WK-ACCT003.hf.com  172.18.39.105    HF\pdulce

# %% [markdown]
# # Stack suspicious Successful Logon and Sysmon Network DFs

# %%
sl_sn_split_appended = sl_df_split.append(sn_df_split)
sl_sn_split_appended['label'] = '1'
sl_sn_split_appended
# Out:
#                  source                target         user label
# 0    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins     1
# 1  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce     1
# 0  VA-WK-ACCT002.hf.com         172.18.39.105  HF\Bbaggins     1
# 1  VA-WK-ACCT003.hf.com         172.18.39.105    HF\pdulce     1

# %% [markdown]
# # Merge suspicious DF with Clean Stacked Successful Logon and Sysmon Network DFs

# %%
src_dst_merged = pd.merge(sl_sn_appended,sl_sn_split_appended,how="left",left_on=["source","target", "user"],right_on=["source","target", "user"])
src_dst_merged
# Out:
#                   source                target         user label
# 0   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite   NaN
# 1   VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit   NaN
# 2     WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins   NaN
# 3     VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown   NaN
# 4     WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins     1
# 5   VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce     1
# 6   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\pdulce   NaN
# 7   VA-WK-ACCT002.hf.com         172.18.39.105  HF\Bbaggins     1
# 8   VA-WK-ACCT003.hf.com         172.18.39.105    HF\pdulce     1
# 9   VA-WK-ACCT002.hf.com         65.52.108.154    HF\gwhite   NaN
# 10    WK-VA-HR002.hf.com          65.55.252.71  HF\Bbaggins   NaN
# 11    WK-VA-HR002.hf.com         172.18.39.105  HF\Bbaggins   NaN
# 12  VA-WK-ACCT003.hf.com         172.18.39.104    HF\pdulce   NaN
# 13  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com  HF\Bbaggins   NaN
# 14  VA-WK-ACCT003.hf.com    VA-WK-HR001.hf.com    HF\pdulce   NaN
# 15  VA-WK-ACCT003.hf.com         65.52.108.154   HF\shobbit   NaN
# 16    VA-WK-HR001.hf.com         40.117.100.83    HF\cbrown   NaN
# 17    VA-WK-HR001.hf.com          13.107.3.128    HF\cbrown   NaN
# 18    VA-WK-HR001.hf.com           13.107.5.88    HF\cbrown   NaN
# 19    VA-WK-HR001.hf.com        40.121.144.182    HF\cbrown   NaN

# %% [markdown]
# # Add label 0 to the rest of the rows

# %%
src_dst = src_dst_merged.fillna('0')
src_dst
# Out:
#                   source                target         user label
# 0   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite     0
# 1   VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit     0
# 2     WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins     0
# 3     VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown     0
# 4     WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins     1
# 5   VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce     1
# 6   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\pdulce     0
# 7   VA-WK-ACCT002.hf.com         172.18.39.105  HF\Bbaggins     1
# 8   VA-WK-ACCT003.hf.com         172.18.39.105    HF\pdulce     1
# 9   VA-WK-ACCT002.hf.com         65.52.108.154    HF\gwhite     0
# 10    WK-VA-HR002.hf.com          65.55.252.71  HF\Bbaggins     0
# 11    WK-VA-HR002.hf.com         172.18.39.105  HF\Bbaggins     0
# 12  VA-WK-ACCT003.hf.com         172.18.39.104    HF\pdulce     0
# 13  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com  HF\Bbaggins     0
# 14  VA-WK-ACCT003.hf.com    VA-WK-HR001.hf.com    HF\pdulce     0
# 15  VA-WK-ACCT003.hf.com         65.52.108.154   HF\shobbit     0
# 16    VA-WK-HR001.hf.com         40.117.100.83    HF\cbrown     0
# 17    VA-WK-HR001.hf.com          13.107.3.128    HF\cbrown     0
# 18    VA-WK-HR001.hf.com           13.107.5.88    HF\cbrown     0
# 19    VA-WK-HR001.hf.com        40.121.144.182    HF\cbrown     0

# %% [markdown]
# # Start Creating a Node list with all systems (Source & Target)

# %%
computers = pd.Index(src_dst['source'].append(src_dst['target']).reset_index(drop=True).unique())
computers
# Out:
# Index([u'VA-WK-ACCT002.hf.com', u'VA-WK-ACCT003.hf.com', u'WK-VA-HR002.hf.com',
#        u'VA-WK-HR001.hf.com', u'HFDC01.hf.com', u'172.18.39.105',
#        u'65.52.108.154', u'65.55.252.71', u'172.18.39.104', u'40.117.100.83',
#        u'13.107.3.128', u'13.107.5.88', u'40.121.144.182'],
#       dtype='object')

# %% [markdown]
# # Start creating a Link list (Source to target)

# %%
temp_links_list = list(src_dst.apply(lambda row: {"source": row['source'], "target": row['target'], "user": row['user'], "label": row['label']}, axis=1))
temp_links_list
# Out:
# [{'label': '0',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\gwhite'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\shobbit'},
#  {'label': '0',
#   'source': u'WK-VA-HR002.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\cbrown'},
#  {'label': '1',
#   'source': u'WK-VA-HR002.hf.com',
#   'target': u'VA-WK-ACCT002.hf.com',
#   'user': u'HF\\Bbaggins'},
#  {'label': '1',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'VA-WK-ACCT003.hf.com',
#   'user': u'HF\\pdulce'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\pdulce'},
#  {'label': '1',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'172.18.39.105',
#   'user': u'HF\\Bbaggins'},
#  {'label': '1',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'172.18.39.105',
#   'user': u'HF\\pdulce'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'65.52.108.154',
#   'user': u'HF\\gwhite'},
#  {'label': '0',
#   'source': u'WK-VA-HR002.hf.com',
#   'target': u'65.55.252.71',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'WK-VA-HR002.hf.com',
#   'target': u'172.18.39.105',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'172.18.39.104',
#   'user': u'HF\\pdulce'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'VA-WK-ACCT003.hf.com',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'VA-WK-HR001.hf.com',
#   'user': u'HF\\pdulce'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'65.52.108.154',
#   'user': u'HF\\shobbit'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'40.117.100.83',
#   'user': u'HF\\cbrown'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'13.107.3.128',
#   'user': u'HF\\cbrown'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'13.107.5.88',
#   'user': u'HF\\cbrown'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'40.121.144.182',
#   'user': u'HF\\cbrown'}]

# %% [markdown]
# # Prepare your Link List

# %%
links = []
for link in temp_links_list:
    record = {"user":link['user'],"label":link['label'], "source":computers.get_loc(link['source']), "target":computers.get_loc(link['target'])}
    links.append(record)

# %%
links
# Out:
# [{'label': '0', 'source': 0, 'target': 4, 'user': u'HF\\gwhite'},
#  {'label': '0', 'source': 1, 'target': 4, 'user': u'HF\\shobbit'},
#  {'label': '0', 'source': 2, 'target': 4, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 3, 'target': 4, 'user': u'HF\\cbrown'},
#  {'label': '1', 'source': 2, 'target': 0, 'user': u'HF\\Bbaggins'},
#  {'label': '1', 'source': 0, 'target': 1, 'user': u'HF\\pdulce'},
#  {'label': '0', 'source': 0, 'target': 4, 'user': u'HF\\pdulce'},
#  {'label': '1', 'source': 0, 'target': 5, 'user': u'HF\\Bbaggins'},
#  {'label': '1', 'source': 1, 'target': 5, 'user': u'HF\\pdulce'},
#  {'label': '0', 'source': 0, 'target': 6, 'user': u'HF\\gwhite'},
#  {'label': '0', 'source': 2, 'target': 7, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 2, 'target': 5, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 1, 'target': 8, 'user': u'HF\\pdulce'},
#  {'label': '0', 'source': 0, 'target': 1, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 1, 'target': 3, 'user': u'HF\\pdulce'},
#  {'label': '0', 'source': 1, 'target': 6, 'user': u'HF\\shobbit'},
#  {'label': '0', 'source': 3, 'target': 9, 'user': u'HF\\cbrown'},
#  {'label': '0', 'source': 3, 'target': 10, 'user': u'HF\\cbrown'},
#  {'label': '0', 'source': 3, 'target': 11, 'user': u'HF\\cbrown'},
#  {'label': '0', 'source': 3, 'target': 12, 'user': u'HF\\cbrown'}]

# %% [markdown]
# # Finalize your Node list

# %%
nodes = []
for c in computers:
    nodes.append({"id":c})

# %%
nodes
# Out:
# [{'id': u'VA-WK-ACCT002.hf.com'},
#  {'id': u'VA-WK-ACCT003.hf.com'},
#  {'id': u'WK-VA-HR002.hf.com'},
#  {'id': u'VA-WK-HR001.hf.com'},
#  {'id': u'HFDC01.hf.com'},
#  {'id': u'172.18.39.105'},
#  {'id': u'65.52.108.154'},
#  {'id': u'65.55.252.71'},
#  {'id': u'172.18.39.104'},
#  {'id': u'40.117.100.83'},
#  {'id': u'13.107.3.128'},
#  {'id': u'13.107.5.88'},
#  {'id': u'40.121.144.182'}]

# %% [markdown]
# # Add your nodes and links and create a dictionary

# %%
json_network = {"nodes":nodes, "links":links}
json_network.keys()
# Out:
# ['nodes', 'links']

# %% [markdown]
# # Convert dictionary into JSON format

# %%
import json
json_dump = json.dumps(json_network, indent=1, sort_keys=True)
print(json_dump)
# Out:
# {
#  "links": [
#   {
#    "label": "0",
#    "source": 0,
#    "target": 4,
#    "user": "HF\\gwhite"
#   },
#   {
#    "label": "0",
#    "source": 1,
#    "target": 4,
#    "user": "HF\\shobbit"
#   },
#   {
#    "label": "0",
#    "source": 2,
#    "target": 4,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 4,
#    "user": "HF\\cbrown"
#   },
#   {
#    "label": "1",
#    "source": 2,
#    "target": 0,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "1",
#    "source": 0,
#    "target": 1,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "0",
#    "source": 0,
#    "target": 4,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "1",
#    "source": 0,
#    "target": 5,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "1",
#    "source": 1,
#    "target": 5,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "0",
#    "source": 0,
#    "target": 6,
#    "user": "HF\\gwhite"
#   },
#   {
#    "label": "0",
#    "source": 2,
#    "target": 7,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 2,
#    "target": 5,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 1,
#    "target": 8,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "0",
#    "source": 0,
#    "target": 1,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 1,
#    "target": 3,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "0",
#    "source": 1,
#    "target": 6,
#    "user": "HF\\shobbit"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 9,
#    "user": "HF\\cbrown"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 10,
#    "user": "HF\\cbrown"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 11,
#    "user": "HF\\cbrown"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 12,
#    "user": "HF\\cbrown"
#   }
#  ],
#  "nodes": [
#   {
#    "id": "VA-WK-ACCT002.hf.com"
#   },
#   {
#    "id": "VA-WK-ACCT003.hf.com"
#   },
#   {
#    "id": "WK-VA-HR002.hf.com"
#   },
#   {
#    "id": "VA-WK-HR001.hf.com"
#   },
#   {
#    "id": "HFDC01.hf.com"
#   },
#   {
#    "id": "172.18.39.105"
#   },
#   {
#    "id": "65.52.108.154"
#   },
#   {
#    "id": "65.55.252.71"
#   },
#   {
#    "id": "172.18.39.104"
#   },
#   {
#    "id": "40.117.100.83"
#   },
#   {
#    "id": "13.107.3.128"
#   },
#   {
#    "id": "13.107.5.88"
#   },
#   {
#    "id": "40.121.144.182"
#   }
#  ]
# }

# %% [markdown]
# # Export it to a JSON file

# %%
filename = 'LM_Basic_Behavior.json'
json_out = open(filename,'w')
json_out.write(json_dump)
json_out.close()

# %% [markdown]
# # Bonus: Use Matplotlib to build a basic nework graph

# %%
indices_network = nx.from_pandas_dataframe(src_dst, 'source', 'target', 'user')

# %%
i = nx.degree(indices_network)
i
# Out:
# {u'13.107.3.128': 1,
#  u'13.107.5.88': 1,
#  u'172.18.39.104': 1,
#  u'172.18.39.105': 3,
#  u'40.117.100.83': 1,
#  u'40.121.144.182': 1,
#  u'65.52.108.154': 2,
#  u'65.55.252.71': 1,
#  u'HFDC01.hf.com': 4,
#  u'VA-WK-ACCT002.hf.com': 5,
#  u'VA-WK-ACCT003.hf.com': 6,
#  u'VA-WK-HR001.hf.com': 6,
#  u'WK-VA-HR002.hf.com': 4}

# %%
nx.draw(indices_network, with_labels=True, graph_layout='shell', nodelist=i.keys(), node_size=[v*60 for v in i.values()])

# %%
plt.show()
