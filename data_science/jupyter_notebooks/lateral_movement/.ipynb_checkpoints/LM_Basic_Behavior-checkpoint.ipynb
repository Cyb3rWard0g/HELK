# %% [markdown]
# # <font color=purple>Basic Data Manipulation & Visualization</font>
# --------------------------------------------------------------------
# ## <font color=green>Goals:</font>
# ------------
# * Show basic ES join queries
# * Learn a little bit of Pandas
# * Learn how to use matplotlib
# * Learn Nodes and Edges format for a Network Graph

# %% [markdown]
# # Import Modules

# %%
from elasticsearch import Elasticsearch
from pandas.io.json import json_normalize
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Connect to your ES via SSH Tunnel

# %%
es = Elasticsearch(['127.0.0.1'], port=9200, timeout=480)

# %% [markdown]
# ## Query your ES for Successful Authentication Logs

# %%
successful_logon_query=es.search(index='winlogbeat-*', 
    body = {
        'size': 10000,
        'query': {
            'bool': {
               'must': [
                    {"match" : {'source_name': "Microsoft-Windows-Security-Auditing" }},
                    {"match": {'event_id': 4624}},
                    {"match": {'event_data.LogonType': 3}}
               ],
               'must_not': [
                    {"match" : {'event_data.IpAddress': "::1" }},
                    {"match": {'event_data.TargetUserName': "ANONYMOUS LOGON"}}
               ],
               "filter": [
                    {"range" : {"@timestamp" : {"gt": "now-72h", "lt" : "now"}}}
               ]    
            }

        }
    })

# %% [markdown]
# # Query ES for WMI Connections

# %%
sysmon_network_wmi=es.search(index='winlogbeat-*', body = {
    'size': 10000,
    'query': {
        'bool': {
           'must': [
               {"match": {'source_name': 'Microsoft-Windows-Sysmon'}},
               {"match": {'event_id': 3}},
               {"match": {'event_data.DestinationPort': 135}},
               {"match": {'event_data.Image' : "C:\\Windows\\System32\\svchost.exe"}}
           ],
           "filter": [
                {"range" : {"@timestamp" : {"gt": "now-72h", "lt" : "now"}}}
           ]    
        }
        
    }
})

# %% [markdown]
# ## Query your ES for Sysmon Network Logs

# %%
sysmon_network_query=es.search(index='winlogbeat-*', body = {
    'size': 10000,
    'query': {
        'bool': {
           'must': [
               {"match": {'source_name': 'Microsoft-Windows-Sysmon'}},
               {"match": {'event_id': 3}}
           ],
           'must_not': [
                {"match" : {'event_data.User': "NT AUTHORITY\SYSTEM"}}
           ],
           "filter": [
                {"range" : {"@timestamp" : {"gt": "now-72h", "lt" : "now"}}}
           ]    
        }
        
    }
})

# %% [markdown]
# # Normalize JSON (results) data into a DataFrame

# %%
sl_normalized=json_normalize(map(lambda x: x["_source"],successful_logon_query['hits']['hits']))
sw_normalized=json_normalize(map(lambda x: x["_source"],sysmon_network_wmi['hits']['hits']))
sn_normalized=json_normalize(map(lambda x: x["_source"],sysmon_network_query['hits']['hits']))

# %%
sl_normalized.head(5)
# Out:
#                  @timestamp @version beat.hostname    beat.name beat.version  \
# 0  2017-08-23T16:08:41.770Z        1   VA-WK-HR001  VA-WK-HR001        5.2.1
# 1  2017-08-23T00:50:14.925Z        1        HFDC01       HFDC01        5.5.0
# 2  2017-08-23T00:59:57.432Z        1        HFDC01       HFDC01        5.5.0
# 3  2017-08-23T01:00:15.336Z        1        HFDC01       HFDC01        5.5.0
# 4  2017-08-23T00:24:56.830Z        1        HFDC01       HFDC01        5.5.0
#
#         computer_name event_data.AuthenticationPackageName  \
# 0  VA-WK-HR001.hf.com                             Kerberos
# 1       HFDC01.hf.com                             Kerberos
# 2       HFDC01.hf.com                             Kerberos
# 3       HFDC01.hf.com                             Kerberos
# 4       HFDC01.hf.com                             Kerberos
#
#   event_data.ImpersonationLevel       event_data.IpAddress event_data.IpPort  \
# 0                           NaN                          -                 -
# 1                        %%1833                172.18.39.2             61331
# 2                        %%1840  fe80::2036:13d7:5626:b29b             61354
# 3                        %%1833                172.18.39.2             61359
# 4                        %%1833  fe80::2036:13d7:5626:b29b             61250
#
#     ...   opcode process_id                           provider_guid  \
# 0   ...     Info        492  {54849625-5478-4994-A5BA-3E3B0328C30D}
# 1   ...     Info        484  {54849625-5478-4994-A5BA-3E3B0328C30D}
# 2   ...     Info        484  {54849625-5478-4994-A5BA-3E3B0328C30D}
# 3   ...     Info        484  {54849625-5478-4994-A5BA-3E3B0328C30D}
# 4   ...     Info        484  {54849625-5478-4994-A5BA-3E3B0328C30D}
#
#   record_number                          source_name  \
# 0        265922  Microsoft-Windows-Security-Auditing
# 1       8836631  Microsoft-Windows-Security-Auditing
# 2       8837698  Microsoft-Windows-Security-Auditing
# 3       8837714  Microsoft-Windows-Security-Auditing
# 4       8836390  Microsoft-Windows-Security-Auditing
#
#                                 tags   task thread_id         type version
# 0  [beats_input_codec_plain_applied]  Logon       400  wineventlog     NaN
# 1  [beats_input_codec_plain_applied]  Logon       316  wineventlog     1.0
# 2  [beats_input_codec_plain_applied]  Logon      4908  wineventlog     1.0
# 3  [beats_input_codec_plain_applied]  Logon       316  wineventlog     1.0
# 4  [beats_input_codec_plain_applied]  Logon       316  wineventlog     1.0
#
# [5 rows x 43 columns]

# %%
sw_normalized.head(5)
# Out:
#                  @timestamp @version beat.hostname beat.name beat.version  \
# 0  2017-08-24T00:47:56.183Z        1        HFDC01    HFDC01        5.5.0
# 1  2017-08-24T03:33:07.761Z        1        HFDC01    HFDC01        5.5.0
# 2  2017-08-24T03:48:08.617Z        1        HFDC01    HFDC01        5.5.0
# 3  2017-08-24T05:18:14.170Z        1        HFDC01    HFDC01        5.5.0
# 4  2017-08-24T06:48:19.968Z        1        HFDC01    HFDC01        5.5.0
#
#    computer_name event_data.DestinationHostname  \
# 0  HFDC01.hf.com                  HFDC01.hf.com
# 1  HFDC01.hf.com                  HFDC01.hf.com
# 2  HFDC01.hf.com                  HFDC01.hf.com
# 3  HFDC01.hf.com                  HFDC01.hf.com
# 4  HFDC01.hf.com                  HFDC01.hf.com
#
#          event_data.DestinationIp event_data.DestinationIsIpv6  \
# 0  fe80:0:0:0:2036:13d7:5626:b29b                         true
# 1  fe80:0:0:0:2036:13d7:5626:b29b                         true
# 2  fe80:0:0:0:2036:13d7:5626:b29b                         true
# 3  fe80:0:0:0:2036:13d7:5626:b29b                         true
# 4  fe80:0:0:0:2036:13d7:5626:b29b                         true
#
#   event_data.DestinationPort   ...                 source_name  \
# 0                        135   ...    Microsoft-Windows-Sysmon
# 1                        135   ...    Microsoft-Windows-Sysmon
# 2                        135   ...    Microsoft-Windows-Sysmon
# 3                        135   ...    Microsoft-Windows-Sysmon
# 4                        135   ...    Microsoft-Windows-Sysmon
#
#                                 tags  \
# 0  [beats_input_codec_plain_applied]
# 1  [beats_input_codec_plain_applied]
# 2  [beats_input_codec_plain_applied]
# 3  [beats_input_codec_plain_applied]
# 4  [beats_input_codec_plain_applied]
#
#                                                 task thread_id         type  \
# 0  Network connection detected (rule: NetworkConn...      1676  wineventlog
# 1  Network connection detected (rule: NetworkConn...      1676  wineventlog
# 2  Network connection detected (rule: NetworkConn...      1676  wineventlog
# 3  Network connection detected (rule: NetworkConn...      1676  wineventlog
# 4  Network connection detected (rule: NetworkConn...      1676  wineventlog
#
#     user.domain user.identifier user.name user.type version
# 0  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 1  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 2  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 3  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 4  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
#
# [5 rows x 41 columns]

# %%
sn_normalized.head(5)
# Out:
#                  @timestamp @version  beat.hostname      beat.name  \
# 0  2017-08-24T03:21:54.070Z        1  VA-WK-ACCT002  VA-WK-ACCT002
# 1  2017-08-24T03:22:34.960Z        1  VA-WK-ACCT002  VA-WK-ACCT002
# 2  2017-08-24T03:23:55.411Z        1  VA-WK-ACCT002  VA-WK-ACCT002
# 3  2017-08-24T03:24:13.534Z        1  VA-WK-ACCT002  VA-WK-ACCT002
# 4  2017-08-24T03:24:25.401Z        1  VA-WK-ACCT002  VA-WK-ACCT002
#
#   beat.version         computer_name event_data.DestinationHostname  \
# 0        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
# 1        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
# 2        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
# 3        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
# 4        5.5.0  VA-WK-ACCT002.hf.com                    WK-VA-HR002
#
#   event_data.DestinationIp event_data.DestinationIsIpv6  \
# 0            172.18.39.105                        false
# 1            172.18.39.105                        false
# 2            172.18.39.105                        false
# 3            172.18.39.105                        false
# 4            172.18.39.105                        false
#
#   event_data.DestinationPort   ...                 source_name  \
# 0                         80   ...    Microsoft-Windows-Sysmon
# 1                         80   ...    Microsoft-Windows-Sysmon
# 2                         80   ...    Microsoft-Windows-Sysmon
# 3                         80   ...    Microsoft-Windows-Sysmon
# 4                         80   ...    Microsoft-Windows-Sysmon
#
#                                 tags  \
# 0  [beats_input_codec_plain_applied]
# 1  [beats_input_codec_plain_applied]
# 2  [beats_input_codec_plain_applied]
# 3  [beats_input_codec_plain_applied]
# 4  [beats_input_codec_plain_applied]
#
#                                                 task thread_id         type  \
# 0  Network connection detected (rule: NetworkConn...      1948  wineventlog
# 1  Network connection detected (rule: NetworkConn...      1948  wineventlog
# 2  Network connection detected (rule: NetworkConn...      1948  wineventlog
# 3  Network connection detected (rule: NetworkConn...      1948  wineventlog
# 4  Network connection detected (rule: NetworkConn...      1948  wineventlog
#
#     user.domain user.identifier user.name user.type version
# 0  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 1  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 2  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 3  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
# 4  NT AUTHORITY        S-1-5-18    SYSTEM      User       5
#
# [5 rows x 41 columns]

# %% [markdown]
# # Clean Successful Logon DataFrame

# %%
sl_df=sl_normalized[sl_normalized["event_data.IpAddress"].str.contains('^(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$')]
sl_df=sl_df[~sl_df['event_data.TargetUserName'].str.contains('.*\$')]
sl_df['user'] = sl_df['event_data.TargetDomainName'] + '\\' + sl_df['event_data.TargetUserName']
sl_df.rename(columns={"event_data.IpAddress":"sourceip", "computer_name":"target"}, inplace=True)
sl_df_clean=sl_df[['sourceip', 'target', 'user', '@timestamp']].reset_index(drop=True)
sl_df_clean.head(10)
# Out:
#         sourceip                target         user                @timestamp
# 0  172.18.39.102         HFDC01.hf.com    HF\gwhite  2017-08-23T15:14:34.934Z
# 1  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T15:16:52.111Z
# 2  172.18.39.101         HFDC01.hf.com  HF\Bbaggins  2017-08-23T14:48:47.058Z
# 3  172.18.39.100         HFDC01.hf.com    HF\cbrown  2017-08-23T13:50:44.437Z
# 4  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T13:52:57.620Z
# 5  172.18.39.101  VA-WK-ACCT002.hf.com  HF\Bbaggins  2017-08-23T14:49:17.484Z
# 6  172.18.39.101  VA-WK-ACCT002.hf.com  HF\Bbaggins  2017-08-23T14:56:18.915Z
# 7  172.18.39.102  VA-WK-ACCT003.hf.com    HF\pdulce  2017-08-23T15:28:01.492Z
# 8  172.18.39.102  VA-WK-ACCT003.hf.com    HF\pdulce  2017-08-23T15:12:34.046Z
# 9  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T14:33:01.250Z

# %% [markdown]
# # Clean Sysmon Network WMI DataFrame

# %%
sw_df=sw_normalized[sw_normalized["event_data.DestinationIp"].str.contains('^(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$')]
sw_df.rename(columns={"event_data.SourceHostname":"source","event_data.SourceIp":"sourceip", "event_data.DestinationIp":"targetip", "event_data.User":"user"}, inplace=True)
sw_df_clean=sw_df[['source', 'targetip', 'user', '@timestamp']]
sw_df_clean.reset_index(drop=True)
sw_df_clean.head(10)
# Out:
#                    source       targetip                          user  \
# 31   VA-WK-ACCT002.hf.com    172.18.39.2           NT AUTHORITY\SYSTEM
# 63   VA-WK-ACCT003.hf.com    172.18.39.2           NT AUTHORITY\SYSTEM
# 80     WK-VA-HR002.hf.com  172.18.39.102  NT AUTHORITY\NETWORK SERVICE
# 81   VA-WK-ACCT002.hf.com  172.18.39.103  NT AUTHORITY\NETWORK SERVICE
# 103    WK-VA-HR002.hf.com  172.18.39.102  NT AUTHORITY\NETWORK SERVICE
# 117    WK-VA-HR002.hf.com  172.18.39.102  NT AUTHORITY\NETWORK SERVICE
# 141  VA-WK-ACCT002.hf.com  172.18.39.103  NT AUTHORITY\NETWORK SERVICE
# 142  VA-WK-ACCT002.hf.com  172.18.39.103  NT AUTHORITY\NETWORK SERVICE
# 176  VA-WK-ACCT003.hf.com    172.18.39.2           NT AUTHORITY\SYSTEM
# 177    VA-WK-HR001.hf.com    172.18.39.2           NT AUTHORITY\SYSTEM
#
#                    @timestamp
# 31   2017-08-24T07:35:23.464Z
# 63   2017-08-23T15:07:49.991Z
# 80   2017-08-23T14:56:12.217Z
# 81   2017-08-23T15:27:51.953Z
# 103  2017-08-23T14:56:12.967Z
# 117  2017-08-23T14:56:12.217Z
# 141  2017-08-23T15:27:51.953Z
# 142  2017-08-23T15:27:57.691Z
# 176  2017-08-23T15:07:51.993Z
# 177  2017-08-23T13:39:28.666Z

# %% [markdown]
# # Clean Sysmon Network DataFrame

# %%
sn_df=sn_normalized[sn_normalized["event_data.SourceIp"].str.contains('^(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$')]
sn_df.rename(columns={"event_data.SourceHostname":"source","event_data.SourceIp":"sourceip", "event_data.DestinationIp":"targetip", "event_data.User":"user"}, inplace=True)
sn_df_clean=sn_df[['source', 'targetip', 'user', '@timestamp']]
sn_df_clean.reset_index(drop=True)
sn_df_clean.head(10)
# Out:
#                  source       targetip         user                @timestamp
# 0  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:21:35.558Z
# 1  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:28.979Z
# 2  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:24:20.654Z
# 3  VA-WK-ACCT003.hf.com  172.18.39.105    HF\pdulce  2017-08-24T03:25:51.320Z
# 4  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:25.637Z
# 5  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:31.867Z
# 6  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:13.761Z
# 7  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:08.125Z
# 8  VA-WK-ACCT003.hf.com  172.18.39.105    HF\pdulce  2017-08-24T03:27:37.349Z
# 9  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:27:44.622Z

# %% [markdown]
# # Create an IP-Computer Map with Sysmon Network Logs

# %%
sysmon_ip_computer_reference=sn_df[['sourceip', 'computer_name']]
sysmon_ip_computer_reference = (sysmon_ip_computer_reference.drop_duplicates()).reset_index(drop=True)
sysmon_ip_computer_reference
# Out:
#         sourceip         computer_name
# 0  172.18.39.102  VA-WK-ACCT002.hf.com
# 1  172.18.39.103  VA-WK-ACCT003.hf.com
# 2  172.18.39.101    WK-VA-HR002.hf.com
# 3  172.18.39.100    VA-WK-HR001.hf.com

# %% [markdown]
# # Merge Successful Logon DF and IP-Computer Map

# %%
sl_df_merged=pd.merge(sl_df_clean,sysmon_ip_computer_reference,how="left",left_on="sourceip",right_on="sourceip")
sl_df_merged.head(10)
# Out:
#         sourceip                target         user                @timestamp  \
# 0  172.18.39.102         HFDC01.hf.com    HF\gwhite  2017-08-23T15:14:34.934Z
# 1  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T15:16:52.111Z
# 2  172.18.39.101         HFDC01.hf.com  HF\Bbaggins  2017-08-23T14:48:47.058Z
# 3  172.18.39.100         HFDC01.hf.com    HF\cbrown  2017-08-23T13:50:44.437Z
# 4  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T13:52:57.620Z
# 5  172.18.39.101  VA-WK-ACCT002.hf.com  HF\Bbaggins  2017-08-23T14:49:17.484Z
# 6  172.18.39.101  VA-WK-ACCT002.hf.com  HF\Bbaggins  2017-08-23T14:56:18.915Z
# 7  172.18.39.102  VA-WK-ACCT003.hf.com    HF\pdulce  2017-08-23T15:28:01.492Z
# 8  172.18.39.102  VA-WK-ACCT003.hf.com    HF\pdulce  2017-08-23T15:12:34.046Z
# 9  172.18.39.103         HFDC01.hf.com   HF\shobbit  2017-08-23T14:33:01.250Z
#
#           computer_name
# 0  VA-WK-ACCT002.hf.com
# 1  VA-WK-ACCT003.hf.com
# 2    WK-VA-HR002.hf.com
# 3    VA-WK-HR001.hf.com
# 4  VA-WK-ACCT003.hf.com
# 5    WK-VA-HR002.hf.com
# 6    WK-VA-HR002.hf.com
# 7  VA-WK-ACCT002.hf.com
# 8  VA-WK-ACCT002.hf.com
# 9  VA-WK-ACCT003.hf.com

# %% [markdown]
# # Merge Sysmon Network WMI DF and IP-Computer Map

# %%
sw_df_merged=pd.merge(sw_df_clean,sysmon_ip_computer_reference,how="left",left_on="targetip",right_on="sourceip")
sw_df_merged.head(10)
# Out:
#                  source       targetip                          user  \
# 0  VA-WK-ACCT002.hf.com    172.18.39.2           NT AUTHORITY\SYSTEM
# 1  VA-WK-ACCT003.hf.com    172.18.39.2           NT AUTHORITY\SYSTEM
# 2    WK-VA-HR002.hf.com  172.18.39.102  NT AUTHORITY\NETWORK SERVICE
# 3  VA-WK-ACCT002.hf.com  172.18.39.103  NT AUTHORITY\NETWORK SERVICE
# 4    WK-VA-HR002.hf.com  172.18.39.102  NT AUTHORITY\NETWORK SERVICE
# 5    WK-VA-HR002.hf.com  172.18.39.102  NT AUTHORITY\NETWORK SERVICE
# 6  VA-WK-ACCT002.hf.com  172.18.39.103  NT AUTHORITY\NETWORK SERVICE
# 7  VA-WK-ACCT002.hf.com  172.18.39.103  NT AUTHORITY\NETWORK SERVICE
# 8  VA-WK-ACCT003.hf.com    172.18.39.2           NT AUTHORITY\SYSTEM
# 9    VA-WK-HR001.hf.com    172.18.39.2           NT AUTHORITY\SYSTEM
#
#                  @timestamp       sourceip         computer_name
# 0  2017-08-24T07:35:23.464Z            NaN                   NaN
# 1  2017-08-23T15:07:49.991Z            NaN                   NaN
# 2  2017-08-23T14:56:12.217Z  172.18.39.102  VA-WK-ACCT002.hf.com
# 3  2017-08-23T15:27:51.953Z  172.18.39.103  VA-WK-ACCT003.hf.com
# 4  2017-08-23T14:56:12.967Z  172.18.39.102  VA-WK-ACCT002.hf.com
# 5  2017-08-23T14:56:12.217Z  172.18.39.102  VA-WK-ACCT002.hf.com
# 6  2017-08-23T15:27:51.953Z  172.18.39.103  VA-WK-ACCT003.hf.com
# 7  2017-08-23T15:27:57.691Z  172.18.39.103  VA-WK-ACCT003.hf.com
# 8  2017-08-23T15:07:51.993Z            NaN                   NaN
# 9  2017-08-23T13:39:28.666Z            NaN                   NaN

# %% [markdown]
# # Merge Sysmon Network DF and IP-Computer Map

# %%
sn_df_merged=pd.merge(sn_df_clean,sysmon_ip_computer_reference,how="left",left_on="targetip",right_on="sourceip")
sn_df_merged.head(10)
# Out:
#                  source       targetip         user                @timestamp  \
# 0  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:21:35.558Z
# 1  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:28.979Z
# 2  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:24:20.654Z
# 3  VA-WK-ACCT003.hf.com  172.18.39.105    HF\pdulce  2017-08-24T03:25:51.320Z
# 4  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:25.637Z
# 5  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:31.867Z
# 6  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:13.761Z
# 7  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:08.125Z
# 8  VA-WK-ACCT003.hf.com  172.18.39.105    HF\pdulce  2017-08-24T03:27:37.349Z
# 9  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:27:44.622Z
#
#   sourceip computer_name
# 0      NaN           NaN
# 1      NaN           NaN
# 2      NaN           NaN
# 3      NaN           NaN
# 4      NaN           NaN
# 5      NaN           NaN
# 6      NaN           NaN
# 7      NaN           NaN
# 8      NaN           NaN
# 9      NaN           NaN

# %% [markdown]
# # Map IP-Computer in Successful Logon Dataframe

# %%
sl_df_resolved=sl_df_merged[['computer_name','target', 'user', '@timestamp']][sl_df_merged['computer_name'].notnull()]
sl_df_resolved.rename(columns={'computer_name':"source"}, inplace=True)
sl_df_resolved.reset_index(drop=True)
sl_df_resolved.head(10)
# Out:
#                  source                target         user  \
# 0  VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite
# 1  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 2    WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins
# 3    VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown
# 4  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 5    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 6    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 8  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 9  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
#
#                  @timestamp
# 0  2017-08-23T15:14:34.934Z
# 1  2017-08-23T15:16:52.111Z
# 2  2017-08-23T14:48:47.058Z
# 3  2017-08-23T13:50:44.437Z
# 4  2017-08-23T13:52:57.620Z
# 5  2017-08-23T14:49:17.484Z
# 6  2017-08-23T14:56:18.915Z
# 7  2017-08-23T15:28:01.492Z
# 8  2017-08-23T15:12:34.046Z
# 9  2017-08-23T14:33:01.250Z

# %% [markdown]
# # Map IP-Computer in Sysmon Network WMI Dataframe

# %%
sw_df_merged.computer_name.fillna(sw_df_merged.targetip, inplace=True)
sw_df_resolved=sw_df_merged[['source','computer_name', 'user', '@timestamp']]
sw_df_resolved.rename(columns={'computer_name':'target'}, inplace=True)
sw_df_resolved.head(10)
# Out:
#                  source                target                          user  \
# 0  VA-WK-ACCT002.hf.com           172.18.39.2           NT AUTHORITY\SYSTEM
# 1  VA-WK-ACCT003.hf.com           172.18.39.2           NT AUTHORITY\SYSTEM
# 2    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  NT AUTHORITY\NETWORK SERVICE
# 3  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com  NT AUTHORITY\NETWORK SERVICE
# 4    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  NT AUTHORITY\NETWORK SERVICE
# 5    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  NT AUTHORITY\NETWORK SERVICE
# 6  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com  NT AUTHORITY\NETWORK SERVICE
# 7  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com  NT AUTHORITY\NETWORK SERVICE
# 8  VA-WK-ACCT003.hf.com           172.18.39.2           NT AUTHORITY\SYSTEM
# 9    VA-WK-HR001.hf.com           172.18.39.2           NT AUTHORITY\SYSTEM
#
#                  @timestamp
# 0  2017-08-24T07:35:23.464Z
# 1  2017-08-23T15:07:49.991Z
# 2  2017-08-23T14:56:12.217Z
# 3  2017-08-23T15:27:51.953Z
# 4  2017-08-23T14:56:12.967Z
# 5  2017-08-23T14:56:12.217Z
# 6  2017-08-23T15:27:51.953Z
# 7  2017-08-23T15:27:57.691Z
# 8  2017-08-23T15:07:51.993Z
# 9  2017-08-23T13:39:28.666Z

# %% [markdown]
# # Map IP-Computer in Sysmon Network Dataframe

# %%
sn_df_merged.computer_name.fillna(sn_df_merged.targetip, inplace=True)
sn_df_resolved=sn_df_merged[['source','computer_name', 'user', '@timestamp']]
sn_df_resolved.rename(columns={'computer_name':'target'}, inplace=True)
sn_df_resolved.head(10)
# Out:
#                  source         target         user                @timestamp
# 0  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:21:35.558Z
# 1  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:22:28.979Z
# 2  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:24:20.654Z
# 3  VA-WK-ACCT003.hf.com  172.18.39.105    HF\pdulce  2017-08-24T03:25:51.320Z
# 4  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:25.637Z
# 5  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:31.867Z
# 6  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:13.761Z
# 7  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:25:08.125Z
# 8  VA-WK-ACCT003.hf.com  172.18.39.105    HF\pdulce  2017-08-24T03:27:37.349Z
# 9  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins  2017-08-24T03:27:44.622Z

# %% [markdown]
# # Stack Successful Logon and Sysmon Network DFs

# %%
sl_sn_appended = sl_df_resolved.append(sn_df_resolved)
sl_sn_appended = sl_sn_appended[['source', 'target', 'user']]
sl_sn_appended = (sl_sn_appended.drop_duplicates()).reset_index(drop=True)
sl_sn_appended
# Out:
#                   source                target         user
# 0   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite
# 1   VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 2     WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins
# 3     VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown
# 4     WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5   VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
# 6   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\pdulce
# 7   VA-WK-ACCT002.hf.com         172.18.39.105  HF\Bbaggins
# 8   VA-WK-ACCT003.hf.com         172.18.39.105    HF\pdulce
# 9   VA-WK-ACCT002.hf.com         65.52.108.154    HF\gwhite
# 10    WK-VA-HR002.hf.com          65.55.252.71  HF\Bbaggins
# 11    WK-VA-HR002.hf.com         172.18.39.105  HF\Bbaggins
# 12  VA-WK-ACCT003.hf.com         172.18.39.104    HF\pdulce
# 13  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com  HF\Bbaggins
# 14  VA-WK-ACCT003.hf.com    VA-WK-HR001.hf.com    HF\pdulce
# 15    WK-VA-HR002.hf.com           172.18.39.2  HF\Bbaggins
# 16  VA-WK-ACCT003.hf.com         65.52.108.154   HF\shobbit
# 17    VA-WK-HR001.hf.com         40.117.100.83    HF\cbrown
# 18    VA-WK-HR001.hf.com          13.107.3.128    HF\cbrown
# 19    VA-WK-HR001.hf.com           13.107.5.88    HF\cbrown
# 20  VA-WK-ACCT002.hf.com           172.18.39.2  HF\Bbaggins
# 21    VA-WK-HR001.hf.com        40.121.144.182    HF\cbrown

# %% [markdown]
# # Take Successful Logon DF and merge it with Sysmon Network DF

# %%
sl_sn_merged = pd.merge(sl_df_resolved,sn_df_resolved,how="left",left_on="target",right_on="source")
sl_sn_merged.head(10)
# Out:
#                source_x              target_x       user_x  \
# 0  VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite
# 1  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 2    WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins
# 3    VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown
# 4  VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit
# 5    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 6    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 7    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 8    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 9    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
#
#                @timestamp_x              source_y       target_y       user_y  \
# 0  2017-08-23T15:14:34.934Z                   NaN            NaN          NaN
# 1  2017-08-23T15:16:52.111Z                   NaN            NaN          NaN
# 2  2017-08-23T14:48:47.058Z                   NaN            NaN          NaN
# 3  2017-08-23T13:50:44.437Z                   NaN            NaN          NaN
# 4  2017-08-23T13:52:57.620Z                   NaN            NaN          NaN
# 5  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 6  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 7  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 8  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 9  2017-08-23T14:49:17.484Z  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
#
#                @timestamp_y
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5  2017-08-24T03:21:54.070Z
# 6  2017-08-24T03:22:34.960Z
# 7  2017-08-24T03:23:55.411Z
# 8  2017-08-24T03:24:13.534Z
# 9  2017-08-24T03:24:25.401Z

# %% [markdown]
# # Use TIME to start looking for a few suspicious (Successful Auth & Sysmon Network Calls)

# %%
sl_sn_merged['@timestamp_x'] = pd.to_datetime(sl_sn_merged['@timestamp_x'])
sl_sn_merged['@timestamp_y'] = pd.to_datetime(sl_sn_merged['@timestamp_y'])

sl_sn_merged = sl_sn_merged[sl_sn_merged.apply(lambda x: (x['@timestamp_y'] - x['@timestamp_x']) < pd.Timedelta("240sec") and x['user_y'] == x['user_x'], axis=1)]

# %%
sl_sn_merged
# Out:
#                   source_x              target_x       user_x  \
# 1567    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1568    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1569    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1570    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1571    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1572    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1573    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1749    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1750    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1751    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1752    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1753    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1754    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1755    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1756    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1757    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1764    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1928    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1929    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1930    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1931    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1932    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1933    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1934    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1935    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1936    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2117    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2118    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2119    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 2120    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# ...                    ...                   ...          ...
# 4996    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 4997    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 4998    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5005    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5169    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5170    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5171    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5172    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5173    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5174    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5175    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5176    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5177    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5358    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5359    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5360    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5361    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5506    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5507    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5508    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5509    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5510    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5511    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5512    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5513    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5514    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5515    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5516    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5517    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 5846  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce
#
#                 @timestamp_x              source_y       target_y  \
# 1567 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1568 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1569 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1570 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1571 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1572 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1573 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1749 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1750 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1751 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1752 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1753 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1754 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1755 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1756 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1757 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1764 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1928 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1929 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1930 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1931 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1932 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1933 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1934 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1935 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 1936 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2117 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2118 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2119 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# 2120 2017-08-23 14:56:18.915  VA-WK-ACCT002.hf.com  172.18.39.105
# ...                      ...                   ...            ...
# 4996 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 4997 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 4998 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5005 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5169 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5170 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5171 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5172 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5173 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5174 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5175 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5176 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5177 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5358 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5359 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5360 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5361 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5506 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5507 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5508 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5509 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5510 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5511 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5512 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5513 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com    172.18.39.2
# 5514 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com    172.18.39.2
# 5515 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5516 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5517 2017-08-23 14:56:18.820  VA-WK-ACCT002.hf.com  172.18.39.105
# 5846 2017-08-23 15:28:02.193  VA-WK-ACCT003.hf.com  172.18.39.105
#
#            user_y            @timestamp_y
# 1567  HF\Bbaggins 2017-08-23 14:58:38.901
# 1568  HF\Bbaggins 2017-08-23 14:59:18.772
# 1569  HF\Bbaggins 2017-08-23 14:57:05.445
# 1570  HF\Bbaggins 2017-08-23 14:57:15.928
# 1571  HF\Bbaggins 2017-08-23 14:57:20.808
# 1572  HF\Bbaggins 2017-08-23 14:57:25.680
# 1573  HF\Bbaggins 2017-08-23 14:59:47.640
# 1749  HF\Bbaggins 2017-08-23 14:56:59.610
# 1750  HF\Bbaggins 2017-08-23 14:57:11.056
# 1751  HF\Bbaggins 2017-08-23 14:57:37.375
# 1752  HF\Bbaggins 2017-08-23 14:57:42.491
# 1753  HF\Bbaggins 2017-08-23 14:57:48.095
# 1754  HF\Bbaggins 2017-08-23 14:58:02.712
# 1755  HF\Bbaggins 2017-08-23 14:58:13.440
# 1756  HF\Bbaggins 2017-08-23 14:59:35.734
# 1757  HF\Bbaggins 2017-08-23 14:59:52.093
# 1764  HF\Bbaggins 2017-08-23 14:58:44.811
# 1928  HF\Bbaggins 2017-08-23 14:59:14.071
# 1929  HF\Bbaggins 2017-08-23 14:57:52.724
# 1930  HF\Bbaggins 2017-08-23 14:58:07.593
# 1931  HF\Bbaggins 2017-08-23 14:59:30.151
# 1932  HF\Bbaggins 2017-08-23 14:59:35.734
# 1933  HF\Bbaggins 2017-08-23 14:59:41.703
# 1934  HF\Bbaggins 2017-08-23 15:00:02.235
# 1935  HF\Bbaggins 2017-08-23 15:00:07.435
# 1936  HF\Bbaggins 2017-08-23 15:00:17.330
# 2117  HF\Bbaggins 2017-08-23 14:57:04.227
# 2118  HF\Bbaggins 2017-08-23 14:57:30.554
# 2119  HF\Bbaggins 2017-08-23 14:59:02.284
# 2120  HF\Bbaggins 2017-08-23 14:59:02.772
# ...           ...                     ...
# 4996  HF\Bbaggins 2017-08-23 14:58:13.440
# 4997  HF\Bbaggins 2017-08-23 14:59:35.734
# 4998  HF\Bbaggins 2017-08-23 14:59:52.093
# 5005  HF\Bbaggins 2017-08-23 14:58:44.811
# 5169  HF\Bbaggins 2017-08-23 14:59:14.071
# 5170  HF\Bbaggins 2017-08-23 14:57:52.724
# 5171  HF\Bbaggins 2017-08-23 14:58:07.593
# 5172  HF\Bbaggins 2017-08-23 14:59:30.151
# 5173  HF\Bbaggins 2017-08-23 14:59:35.734
# 5174  HF\Bbaggins 2017-08-23 14:59:41.703
# 5175  HF\Bbaggins 2017-08-23 15:00:02.235
# 5176  HF\Bbaggins 2017-08-23 15:00:07.435
# 5177  HF\Bbaggins 2017-08-23 15:00:17.330
# 5358  HF\Bbaggins 2017-08-23 14:57:04.227
# 5359  HF\Bbaggins 2017-08-23 14:57:30.554
# 5360  HF\Bbaggins 2017-08-23 14:59:02.284
# 5361  HF\Bbaggins 2017-08-23 14:59:02.772
# 5506  HF\Bbaggins 2017-08-23 14:57:57.840
# 5507  HF\Bbaggins 2017-08-23 14:58:17.582
# 5508  HF\Bbaggins 2017-08-23 14:58:32.884
# 5509  HF\Bbaggins 2017-08-23 14:58:50.663
# 5510  HF\Bbaggins 2017-08-23 14:58:55.126
# 5511  HF\Bbaggins 2017-08-23 14:59:08.377
# 5512  HF\Bbaggins 2017-08-23 14:59:23.966
# 5513  HF\Bbaggins 2017-08-23 14:59:35.981
# 5514  HF\Bbaggins 2017-08-23 14:59:37.718
# 5515  HF\Bbaggins 2017-08-23 14:59:42.198
# 5516  HF\Bbaggins 2017-08-23 14:59:57.535
# 5517  HF\Bbaggins 2017-08-23 15:00:13.372
# 5846    HF\pdulce 2017-08-23 15:31:54.620
#
# [86 rows x 8 columns]

# %% [markdown]
# # Grab suspicious Successful Logon activity

# %%
sl_df_split = sl_sn_merged[['source_x', 'target_x', 'user_x']]
sl_df_split.rename(columns={'source_x':'source', 'target_x':'target', 'user_x':'user'}, inplace=True)
sl_df_split = (sl_df_split.drop_duplicates()).reset_index(drop=True)
sl_df_split
# Out:
#                  source                target         user
# 0    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins
# 1  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce

# %% [markdown]
# # Grab suspicious Sysmon Network activity

# %%
sn_df_split = sl_sn_merged[['source_y', 'target_y', 'user_y']]
sn_df_split.rename(columns={'source_y':'source', 'target_y':'target', 'user_y':'user'}, inplace=True)
sn_df_split = (sn_df_split.drop_duplicates()).reset_index(drop=True)
sn_df_split
# Out:
#                  source         target         user
# 0  VA-WK-ACCT002.hf.com  172.18.39.105  HF\Bbaggins
# 1  VA-WK-ACCT002.hf.com    172.18.39.2  HF\Bbaggins
# 2  VA-WK-ACCT003.hf.com  172.18.39.105    HF\pdulce

# %% [markdown]
# # Stack suspicious Successful Logon and Sysmon Network DFs

# %%
sl_sn_split_appended = sl_df_split.append(sn_df_split)
sl_sn_split_appended['label'] = '1'
sl_sn_split_appended
# Out:
#                  source                target         user label
# 0    WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins     1
# 1  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce     1
# 0  VA-WK-ACCT002.hf.com         172.18.39.105  HF\Bbaggins     1
# 1  VA-WK-ACCT002.hf.com           172.18.39.2  HF\Bbaggins     1
# 2  VA-WK-ACCT003.hf.com         172.18.39.105    HF\pdulce     1

# %% [markdown]
# # Merge suspicious DF with Clean Stacked Successful Logon and Sysmon Network DFs

# %%
src_dst_merged = pd.merge(sl_sn_appended,sl_sn_split_appended,how="left",left_on=["source","target", "user"],right_on=["source","target", "user"])
src_dst_merged
# Out:
#                   source                target         user label
# 0   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite   NaN
# 1   VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit   NaN
# 2     WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins   NaN
# 3     VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown   NaN
# 4     WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins     1
# 5   VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce     1
# 6   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\pdulce   NaN
# 7   VA-WK-ACCT002.hf.com         172.18.39.105  HF\Bbaggins     1
# 8   VA-WK-ACCT003.hf.com         172.18.39.105    HF\pdulce     1
# 9     WK-VA-HR002.hf.com          65.55.252.71  HF\Bbaggins   NaN
# 10    WK-VA-HR002.hf.com         172.18.39.105  HF\Bbaggins   NaN
# 11  VA-WK-ACCT002.hf.com         65.52.108.154    HF\gwhite   NaN
# 12  VA-WK-ACCT003.hf.com         172.18.39.104    HF\pdulce   NaN
# 13  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com  HF\Bbaggins   NaN
# 14  VA-WK-ACCT003.hf.com    VA-WK-HR001.hf.com    HF\pdulce   NaN
# 15    WK-VA-HR002.hf.com           172.18.39.2  HF\Bbaggins   NaN
# 16  VA-WK-ACCT003.hf.com         65.52.108.154   HF\shobbit   NaN
# 17    VA-WK-HR001.hf.com         40.117.100.83    HF\cbrown   NaN
# 18    VA-WK-HR001.hf.com          13.107.3.128    HF\cbrown   NaN
# 19    VA-WK-HR001.hf.com           13.107.5.88    HF\cbrown   NaN
# 20  VA-WK-ACCT002.hf.com           172.18.39.2  HF\Bbaggins     1
# 21    VA-WK-HR001.hf.com        40.121.144.182    HF\cbrown   NaN

# %% [markdown]
# # Add label 0 to the rest of the rows

# %%
src_dst = src_dst_merged.fillna('0')
src_dst
# Out:
#                   source                target         user label
# 0   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\gwhite     0
# 1   VA-WK-ACCT003.hf.com         HFDC01.hf.com   HF\shobbit     0
# 2     WK-VA-HR002.hf.com         HFDC01.hf.com  HF\Bbaggins     0
# 3     VA-WK-HR001.hf.com         HFDC01.hf.com    HF\cbrown     0
# 4     WK-VA-HR002.hf.com  VA-WK-ACCT002.hf.com  HF\Bbaggins     1
# 5   VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com    HF\pdulce     1
# 6   VA-WK-ACCT002.hf.com         HFDC01.hf.com    HF\pdulce     0
# 7   VA-WK-ACCT002.hf.com         172.18.39.105  HF\Bbaggins     1
# 8   VA-WK-ACCT003.hf.com         172.18.39.105    HF\pdulce     1
# 9     WK-VA-HR002.hf.com          65.55.252.71  HF\Bbaggins     0
# 10    WK-VA-HR002.hf.com         172.18.39.105  HF\Bbaggins     0
# 11  VA-WK-ACCT002.hf.com         65.52.108.154    HF\gwhite     0
# 12  VA-WK-ACCT003.hf.com         172.18.39.104    HF\pdulce     0
# 13  VA-WK-ACCT002.hf.com  VA-WK-ACCT003.hf.com  HF\Bbaggins     0
# 14  VA-WK-ACCT003.hf.com    VA-WK-HR001.hf.com    HF\pdulce     0
# 15    WK-VA-HR002.hf.com           172.18.39.2  HF\Bbaggins     0
# 16  VA-WK-ACCT003.hf.com         65.52.108.154   HF\shobbit     0
# 17    VA-WK-HR001.hf.com         40.117.100.83    HF\cbrown     0
# 18    VA-WK-HR001.hf.com          13.107.3.128    HF\cbrown     0
# 19    VA-WK-HR001.hf.com           13.107.5.88    HF\cbrown     0
# 20  VA-WK-ACCT002.hf.com           172.18.39.2  HF\Bbaggins     1
# 21    VA-WK-HR001.hf.com        40.121.144.182    HF\cbrown     0

# %% [markdown]
# # Start Creating a Node list with all systems (Source & Target)

# %%
computers = pd.Index(src_dst['source'].append(src_dst['target']).reset_index(drop=True).unique())
computers
# Out:
# Index([u'VA-WK-ACCT002.hf.com', u'VA-WK-ACCT003.hf.com', u'WK-VA-HR002.hf.com',
#        u'VA-WK-HR001.hf.com', u'HFDC01.hf.com', u'172.18.39.105',
#        u'65.55.252.71', u'65.52.108.154', u'172.18.39.104', u'172.18.39.2',
#        u'40.117.100.83', u'13.107.3.128', u'13.107.5.88', u'40.121.144.182'],
#       dtype='object')

# %% [markdown]
# # Start creating a Link list (Source to target)

# %%
temp_links_list = list(src_dst.apply(lambda row: {"source": row['source'], "target": row['target'], "user": row['user'], "label": row['label']}, axis=1))
temp_links_list
# Out:
# [{'label': '0',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\gwhite'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\shobbit'},
#  {'label': '0',
#   'source': u'WK-VA-HR002.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\cbrown'},
#  {'label': '1',
#   'source': u'WK-VA-HR002.hf.com',
#   'target': u'VA-WK-ACCT002.hf.com',
#   'user': u'HF\\Bbaggins'},
#  {'label': '1',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'VA-WK-ACCT003.hf.com',
#   'user': u'HF\\pdulce'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'HFDC01.hf.com',
#   'user': u'HF\\pdulce'},
#  {'label': '1',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'172.18.39.105',
#   'user': u'HF\\Bbaggins'},
#  {'label': '1',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'172.18.39.105',
#   'user': u'HF\\pdulce'},
#  {'label': '0',
#   'source': u'WK-VA-HR002.hf.com',
#   'target': u'65.55.252.71',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'WK-VA-HR002.hf.com',
#   'target': u'172.18.39.105',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'65.52.108.154',
#   'user': u'HF\\gwhite'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'172.18.39.104',
#   'user': u'HF\\pdulce'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'VA-WK-ACCT003.hf.com',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'VA-WK-HR001.hf.com',
#   'user': u'HF\\pdulce'},
#  {'label': '0',
#   'source': u'WK-VA-HR002.hf.com',
#   'target': u'172.18.39.2',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'VA-WK-ACCT003.hf.com',
#   'target': u'65.52.108.154',
#   'user': u'HF\\shobbit'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'40.117.100.83',
#   'user': u'HF\\cbrown'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'13.107.3.128',
#   'user': u'HF\\cbrown'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'13.107.5.88',
#   'user': u'HF\\cbrown'},
#  {'label': '1',
#   'source': u'VA-WK-ACCT002.hf.com',
#   'target': u'172.18.39.2',
#   'user': u'HF\\Bbaggins'},
#  {'label': '0',
#   'source': u'VA-WK-HR001.hf.com',
#   'target': u'40.121.144.182',
#   'user': u'HF\\cbrown'}]

# %% [markdown]
# # Prepare your Link List

# %%
links = []
for link in temp_links_list:
    record = {"user":link['user'],"label":link['label'], "source":computers.get_loc(link['source']), "target":computers.get_loc(link['target'])}
    links.append(record)

# %%
links
# Out:
# [{'label': '0', 'source': 0, 'target': 4, 'user': u'HF\\gwhite'},
#  {'label': '0', 'source': 1, 'target': 4, 'user': u'HF\\shobbit'},
#  {'label': '0', 'source': 2, 'target': 4, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 3, 'target': 4, 'user': u'HF\\cbrown'},
#  {'label': '1', 'source': 2, 'target': 0, 'user': u'HF\\Bbaggins'},
#  {'label': '1', 'source': 0, 'target': 1, 'user': u'HF\\pdulce'},
#  {'label': '0', 'source': 0, 'target': 4, 'user': u'HF\\pdulce'},
#  {'label': '1', 'source': 0, 'target': 5, 'user': u'HF\\Bbaggins'},
#  {'label': '1', 'source': 1, 'target': 5, 'user': u'HF\\pdulce'},
#  {'label': '0', 'source': 2, 'target': 6, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 2, 'target': 5, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 0, 'target': 7, 'user': u'HF\\gwhite'},
#  {'label': '0', 'source': 1, 'target': 8, 'user': u'HF\\pdulce'},
#  {'label': '0', 'source': 0, 'target': 1, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 1, 'target': 3, 'user': u'HF\\pdulce'},
#  {'label': '0', 'source': 2, 'target': 9, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 1, 'target': 7, 'user': u'HF\\shobbit'},
#  {'label': '0', 'source': 3, 'target': 10, 'user': u'HF\\cbrown'},
#  {'label': '0', 'source': 3, 'target': 11, 'user': u'HF\\cbrown'},
#  {'label': '0', 'source': 3, 'target': 12, 'user': u'HF\\cbrown'},
#  {'label': '1', 'source': 0, 'target': 9, 'user': u'HF\\Bbaggins'},
#  {'label': '0', 'source': 3, 'target': 13, 'user': u'HF\\cbrown'}]

# %% [markdown]
# # Finalize your Node list

# %%
nodes = []
for c in computers:
    nodes.append({"id":c})

# %%
nodes
# Out:
# [{'id': u'VA-WK-ACCT002.hf.com'},
#  {'id': u'VA-WK-ACCT003.hf.com'},
#  {'id': u'WK-VA-HR002.hf.com'},
#  {'id': u'VA-WK-HR001.hf.com'},
#  {'id': u'HFDC01.hf.com'},
#  {'id': u'172.18.39.105'},
#  {'id': u'65.55.252.71'},
#  {'id': u'65.52.108.154'},
#  {'id': u'172.18.39.104'},
#  {'id': u'172.18.39.2'},
#  {'id': u'40.117.100.83'},
#  {'id': u'13.107.3.128'},
#  {'id': u'13.107.5.88'},
#  {'id': u'40.121.144.182'}]

# %% [markdown]
# # Add your nodes and links and create a dictionary

# %%
json_network = {"nodes":nodes, "links":links}
json_network.keys()
# Out:
# ['nodes', 'links']

# %% [markdown]
# # Convert dictionary into JSON format

# %%
import json
json_dump = json.dumps(json_network, indent=1, sort_keys=True)
print(json_dump)
# Out:
# {
#  "links": [
#   {
#    "label": "0",
#    "source": 0,
#    "target": 4,
#    "user": "HF\\gwhite"
#   },
#   {
#    "label": "0",
#    "source": 1,
#    "target": 4,
#    "user": "HF\\shobbit"
#   },
#   {
#    "label": "0",
#    "source": 2,
#    "target": 4,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 4,
#    "user": "HF\\cbrown"
#   },
#   {
#    "label": "1",
#    "source": 2,
#    "target": 0,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "1",
#    "source": 0,
#    "target": 1,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "0",
#    "source": 0,
#    "target": 4,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "1",
#    "source": 0,
#    "target": 5,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "1",
#    "source": 1,
#    "target": 5,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "0",
#    "source": 2,
#    "target": 6,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 2,
#    "target": 5,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 0,
#    "target": 7,
#    "user": "HF\\gwhite"
#   },
#   {
#    "label": "0",
#    "source": 1,
#    "target": 8,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "0",
#    "source": 0,
#    "target": 1,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 1,
#    "target": 3,
#    "user": "HF\\pdulce"
#   },
#   {
#    "label": "0",
#    "source": 2,
#    "target": 9,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 1,
#    "target": 7,
#    "user": "HF\\shobbit"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 10,
#    "user": "HF\\cbrown"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 11,
#    "user": "HF\\cbrown"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 12,
#    "user": "HF\\cbrown"
#   },
#   {
#    "label": "1",
#    "source": 0,
#    "target": 9,
#    "user": "HF\\Bbaggins"
#   },
#   {
#    "label": "0",
#    "source": 3,
#    "target": 13,
#    "user": "HF\\cbrown"
#   }
#  ],
#  "nodes": [
#   {
#    "id": "VA-WK-ACCT002.hf.com"
#   },
#   {
#    "id": "VA-WK-ACCT003.hf.com"
#   },
#   {
#    "id": "WK-VA-HR002.hf.com"
#   },
#   {
#    "id": "VA-WK-HR001.hf.com"
#   },
#   {
#    "id": "HFDC01.hf.com"
#   },
#   {
#    "id": "172.18.39.105"
#   },
#   {
#    "id": "65.55.252.71"
#   },
#   {
#    "id": "65.52.108.154"
#   },
#   {
#    "id": "172.18.39.104"
#   },
#   {
#    "id": "172.18.39.2"
#   },
#   {
#    "id": "40.117.100.83"
#   },
#   {
#    "id": "13.107.3.128"
#   },
#   {
#    "id": "13.107.5.88"
#   },
#   {
#    "id": "40.121.144.182"
#   }
#  ]
# }

# %% [markdown]
# # Export it to a JSON file

# %%
filename = 'LM_Basic_Behavior.json'
json_out = open(filename,'w')
json_out.write(json_dump)
json_out.close()

# %% [markdown]
# # Bonus: Use Matplotlib to build a basic nework graph

# %%
indices_network = nx.from_pandas_dataframe(src_dst, 'source', 'target', 'user')

# %%
i = nx.degree(indices_network)
i
# Out:
# {u'13.107.3.128': 1,
#  u'13.107.5.88': 1,
#  u'172.18.39.104': 1,
#  u'172.18.39.105': 3,
#  u'172.18.39.2': 2,
#  u'40.117.100.83': 1,
#  u'40.121.144.182': 1,
#  u'65.52.108.154': 2,
#  u'65.55.252.71': 1,
#  u'HFDC01.hf.com': 4,
#  u'VA-WK-ACCT002.hf.com': 6,
#  u'VA-WK-ACCT003.hf.com': 6,
#  u'VA-WK-HR001.hf.com': 6,
#  u'WK-VA-HR002.hf.com': 5}

# %%
nx.draw(indices_network, with_labels=True, graph_layout='shell', nodelist=i.keys(), node_size=[v*60 for v in i.values()])

# %%
plt.show()
